# %% [markdown]
# <a href="https://colab.research.google.com/github/aulia20-kka/kka-semester-1-/blob/main/3_simple_app_kerucut_volume_XI_1_Luluk_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Luluk viani aulia
# Kelas : XI.1
# No.absen : 23
# Nama kelompok : Perfect

# %% [markdown]
# ##Aplikasi sederhana menghitung volume kerucut

# %%
jari_jari = float(input("masukkan jari jari kerucut: "))
tinggi = float(input("masukkan tinggi kerucut: "))
pi = 3.14

volume = (1/3) * pi * (jari_jari**2) * tinggi
print(f"volume kerucut adalah {volume:.2f} cm^3")
# Out:
# masukkan jari jari kerucut: 10.7
# masukkan tinggi kerucut: 17.8
# volume kerucut adalah 2133.03 cm^3
