# %% [markdown]
# <a href="https://colab.research.google.com/github/aulia20-kka/kka-semester-1-/blob/main/2_tipe_variabel_Luluk_RH_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Nama : Luluk viani aulia
# ##Kelas : XI.1
# ##No. Absen : 23

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "lulukauliakka2025@gmail.com"
print(email_user_1)
# Out:
# lulukauliakka2025@gmail.com

# %%
sabun_lifebuoy = 15000
print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Penulisan variabel hanya boleh menggunakan huruf, angka, dan underscore
# Tidak boleh menggunakan spasi
nama siswa = "Luluk"
print(nama siswa)
# Out:
#   File "/tmp/ipython-input-1791443872.py", line 3
#     nama siswa = "Luluk"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali angka
1_nama_siswa = "Luluk"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-127513871.py", line 2
#     1_nama_siswa = "Luluk"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Luluk"
print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1534784580.py in <cell line: 0>()
#       1 # Penulisan variabel itu case sensitive/sensitif capslock
#       2 nama_siswa_1 = "Luluk"
# ----> 3 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di Bahasa Python
prin = "Luluk"
print(prin)
# Out:
# Luluk

# %%
end = "Luluk"
print (end)
# Out:
# Luluk

# %%
#Deskriptif
_ = "Luluk"
print(_)
# Out:
# Luluk

# %%
# Tidak boleh pakai kata kunci python
# Kalau error, harus disconnect dulu
# print = "Luluk"

# print(print)

# %%
end = "Naufal"
print(end)
# Out:
# Naufal

# %%
#Tidak deskriptif
_ = "Favian" #Bisa, tapi tidak jelas/tidak deskriptif
print(_)

#Seharusnya yang deskriptif :
nama_pelanggan = "Faviana"
print(nama_pelanggan)
# Out:
# Favian
# Faviana

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single assignment

# %%
nama_siswa_2 = "Luluk"
nama_siswa_3 = "Tun"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Luluk
# Tun

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Luluk", "Tun"
print(unama_siswa_4)
print(nama_siswa_5)
# Out:
# Luluk
# Tun

# %% [markdown]
# ##Chain Assignment

# %%
nilai_luluk = nilai_celo = 100
print(nilai_luluk)
print(nilai_celo)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_luluk = 95
print(nilai_luluk)
# Out:
# 95

# %% [markdown]
# #Latihan Soal

# %%
susu = 15000
roti = 12000
telur = 24000
print("1. single assignment ")
print(f" susu = Rp{susu:,}")
print(f" roti = Rp{roti:,}")
print(f" telur = Rp{telur:,}\n")
# Out:
# 1. single assignment
#  susu = Rp15,000
#  roti = Rp12,000
#  telur = Rp24,000

# %%
gula,minyak = 14000,20000
print("2.Multiple Assignment")
print(f" gula = Rp{gula:,}")
print(f" minyak = Rp{minyak:,}\n")
# Out:
# 2.Multiple Assignment
#  gula = Rp14,000
#  minyak = Rp20,000

# %%
mie_ayam = mie_soto = mie_kari = 3500
print("3. Pengisian Nilai sama")
print(f" mie_ayam = Rp{mie_ayam:,}")
print(f" mie_soto = Rp{mie_soto:,}")
print(f" mie_kari = Rp{mie_kari:,}")
# Out:
# 3. Pengisian Nilai sama
#  mie_ayam = Rp3,500
#  mie_soto = Rp3,500
#  mie_kari = Rp3,500

# %%
print("4. Swap (sebelum swap)")
print(f" susu = Rp{susu:,},roti = Rp{roti:,} susu, roti = roti, susu
print(" (setelah swap)")
print(f"susu = Rp{susu:,} roti = Rp{roti:,}\n")
# Out:
#   File "/tmp/ipython-input-3094547562.py", line 2
#     print(f" susu = Rp{susu:,},roti = Rp{roti:,} susu, roti = roti, susu
#           ^
# SyntaxError: unterminated f-string literal (detected at line 2)

# %%
print("5. Perubahan Nilai Variabel")
print(f" telur(sebelum) = Rp{telur:,}")
print(f"

BELUM SELESAI.

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel print(5000*3)
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3
print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3
print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok
print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok
print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Latihan soal 2

# %%
#Satu kardus berisi 24 botol minum. Jika ada 3 kardus, berapa jumlah botol?

print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5
type(berat_telur)
# Out:
# float

# %%
nama = "Shinta"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
remidi = True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# ##input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3266789932.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2
print(f"Luas persegi panjang adalah {luas_2} cm^2" )
# Out:
# Masukkan panjang persegi: 5
# Masukkan lebar persegi: 2
# Luas persegi panjang adalah 10 cm^2

# %% [markdown]
# ##latihan soal

# %%
panjang_1 = int(input("Masukkan panjang: "))
lebar_1 = int(input("Masukkan lebar: "))
tinggi_1 = int(input("Masukkan tinggi: "))

volume_1 = panjang_1*lebar_1*tinggi_1
print(f"Volume balok tersebut adalah {volume_1} cm^3")
# Out:
# Masukkan panjang: 10
# Masukkan lebar: 5
# Masukkan tinggi: 4
# Volume balok tersebut adalah 200 cm^3

# %% [markdown]
# #Konversi tipe data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# #Operator Perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(1 != 1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>b)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >= iq_min and 170>= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
BB_min = 50
umur_min = 25

tinggi_farel = 170
BB_farel = 55
umur_farel = 23

print(tinggi_farel >= tinggi_min and BB_farel >= BB_min and umur_farel <= umur_min)
# Out:
# True
