# %% [markdown]
# <a href="https://colab.research.google.com/github/aulia20-kka/kka-semester-1-/blob/main/1_Fungsi_Print_Luluk_viani_aulia_%5BXI_1%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print ("Halo Dunia!")
# Out:
# Halo Dunia!

# %%
print ('Selamat datang di Python')
# Out:
# Selamat datang di Python

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
nama = "luluk"
print (nama)
# Out:
# luluk

# %%
umur = "16"
print (umur)
# Out:
# 16

# %%
nama = "luluk"
print("halo nama ku " + nama)
# Out:
# halo nama ku luluk

# %%
umur = "16"
print("umur saya adalah " + str(umur)+ " tahun")
# Out:
# umur saya adalah 16 tahun

# %% [markdown]
# Escape Character

# %%
print ("Nama : Luluk Viani Aulia")
print ("Kelas : XI.1")
print ("Nomor Absen : 23")
# Out:
# Nama : Luluk Viani Aulia
# Kelas : XI.1
# Nomor Absen : 23

# %%
print ("Nama\t\t: Luluk Viani Aulia\nKelas\t\t: XI.1\nNomor Absen\t: 23")
# Out:
# Nama		: Luluk Viani Aulia
# Kelas		: XI.1
# Nomor Absen	: 23

# %%
print ("""Nama : Luluk Viani Aulia
Kelas : XI.1
Nomor Absen : 23""")
# Out:
# Nama : Luluk Viani Aulia
# Kelas : XI.1
# Nomor Absen : 23

# %%
harga_telur = 26000
print ("Harga telur per 1 kg adalah", harga_telur)
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000
print ("harga telur per 1 kg adalah " + str (harga_telur))
# Out:
# harga telur per 1 kg adalah 26000

# %%
nama_pembeli = "Luluk"
print ("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Luluk

# %% [markdown]
# LATIHAN SOAL

# %%
print ("Hari ini saya bahagia belajar bahasa Python")
# Out:
# Hari ini saya bahagia belajar bahasa Python

# %%
mata_pelajaran_favorite = 3107091
print (mata_pelajaran_favorite)
# Out:
# 3107091

# %%
nilai_kka = 100
print (nilai_kka)
# Out:
# 100

# %%
nilai_kka = 100
print(f"nilai kka saya adalah {nilai_kka} loh!")
# Out:
# nilai kka saya adalah 100 loh!

# %%
nilai_kka = "100"
print("nilai kka saya adalah " + str(nilai_kka) )
# Out:
# nilai kka saya adalah 100

# %%
nilai_kka = 100
print ("nilai kka saya adalah " , nilai_kka)
# Out:
# nilai kka saya adalah  100

# %% [markdown]
# PARAMETER FUNGSI PRINT

# %%
print ("A", "B", "C")
# Out:
# A B C

# %%
print ("A", "B", "C", sep= "-")
# Out:
# A-B-C

# %%
print("2025", "08", "11", sep="/")
# Out:
# 2025/08/11

# %%
print ("Hello", end=" ") #
# Out:
# Hello

# %%
print ("A", end="-") #
print ("B")
# Out:
# A-B

# %%
print("Bu Shinta berkata, \"berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\\Jadwal Pelajaran\\Kelas XI Semester I\"")
print("\n")
print("Jadwal Pelajaran Mingguan")
print("==================================================")
print("Jam\tSenin\t\tSelasa\t\tRabu")
print("Jam 1\tMatematika\tBahasa\t\tInformatika")
print("Jam 2\tBahasa Ing.\tSejarah\t\tMa\'rifatullah")
print("Jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\Jadwal Pelajaran\Kelas XI Semester I"
#
#
# Jadwal Pelajaran Mingguan
# ...
# Jam	Senin		Selasa		Rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga	Biologi
